# %%
import sys
sys.path.append("..")
from geoclidean_env_euclid import *
import numpy as np
import os
import shutil

# %%
concept = [
    'l1 = line(p1(), p2())',
    'c1* = circle(p1(), p2())',
    'c2* = circle(p2(), p1())',
    'l2 = line(p1(), p3(c1, c2))',
    'l3 = line(p2(), p3()))'
]


for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)

# %%
concept = [
    'c1 = circle(p1(), p2())',
    'c2 = circle(p3(c1), p4())',
    'l3 = line(p5(c1), p6(c1, c2))'
]

for i in range(3):
    generate_concept(concept, mark_points=True, show_plots=True)
# Out:
# POINT (7.950635956062806 4.27956015900679)
# array('d', [7.950635956062806]) array('d', [4.27956015900679])
# POINT (6.592599570026795 2.386095423625374)
# array('d', [6.592599570026795]) array('d', [2.386095423625374])
# POINT (10.269538421331156 4.051168200954122)
# array('d', [10.269538421331156]) array('d', [4.051168200954122])
# POINT (2.0300590458297414 4.753669574217167)
# array('d', [2.0300590458297414]) array('d', [4.753669574217167])
# POINT (9.110375779193836 15.497923015048578)
# array('d', [9.110375779193836]) array('d', [15.497923015048578])
# POINT (14.530587903427119 11.519689390679723)
# array('d', [14.530587903427119]) array('d', [11.519689390679723])
# POINT (11.683336168393659 9.286247147993606)
# array('d', [11.683336168393659]) array('d', [9.286247147993606])
# POINT (13.356564192647754 12.265193187250134)
# array('d', [13.356564192647754]) array('d', [12.265193187250134])
# POINT (2.3869062699490424 15.497923015048578)
# array('d', [2.3869062699490424]) array('d', [15.497923015048578])
# POINT (14.398100973179746 11.354506904027025)
# array('d', [14.398100973179746]) array('d', [11.354506904027025])
# POINT (9.696905852380839 8.993553525900703)
# array('d', [9.696905852380839]) array('d', [8.993553525900703])
# POINT (8.24033160338714 14.415712349681952)
# array('d', [8.24033160338714]) array('d', [14.415712349681952])
# POINT (5.726930106035503 5.023577779555367)
# array('d', [5.726930106035503]) array('d', [5.023577779555367])
# POINT (4.5473427925289265 7.417203391027684)
# array('d', [4.5473427925289265]) array('d', [7.417203391027684])
# POINT (4.082512309607015 8.993553525900703)
# array('d', [4.082512309607015]) array('d', [8.993553525900703])
# POINT (8.006566481786685 3.6425850864700378)
# array('d', [8.006566481786685]) array('d', [3.6425850864700378])
# POINT (15.06866416959624 0.1973943094371151)
# array('d', [15.06866416959624]) array('d', [0.1973943094371151])
# POINT (15.105324710998733 1.4063102809235097)
# array('d', [15.105324710998733]) array('d', [1.4063102809235097])
# POINT (16.226056435452325 -0.1536967960431163)
# array('d', [16.226056435452325]) array('d', [-0.15369679604311626])
# POINT (6.127384905504604 10.948080723661308)
# array('d', [6.127384905504604]) array('d', [10.948080723661308])
# POINT (3.586656110609118 3.0180942629644836)
# array('d', [3.586656110609118]) array('d', [3.0180942629644836])
# POINT (15.390035025990246 11.26228975689095)
# array('d', [15.390035025990246]) array('d', [11.26228975689095])
# POINT (16.888163774547174 8.527759137377302)
# array('d', [16.888163774547174]) array('d', [8.527759137377302])
# POINT (9.690652857992445 13.750001289368024)
# array('d', [9.690652857992445]) array('d', [13.750001289368024])
# POINT (17.984104258185177 3.0180942629644836)
# array('d', [17.984104258185177]) array('d', [3.0180942629644836])
# POINT (11.107612855254956 15.275539294865965)
# array('d', [11.107612855254956]) array('d', [15.275539294865965])
