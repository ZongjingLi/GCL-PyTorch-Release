# %%
import sys
sys.path.append("..")
from geoclidean_env_euclid import *
import numpy as np
import os
import shutil

# %%
concept = [
    'l1 = line(p1(), p2())',
    'c1* = circle(p1(), p2())',
    'c2* = circle(p2(), p1())',
    'l2 = line(p1(), p3(c1, c2))',
    'l3 = line(p2(), p3()))'
]


for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)

# %%
concept = [
    'c1 = circle(p1(), p2())',
    'c2 = circle(p3(c1), p4())',
    'l3 = line(p5(c1), p6(c1, c2))'
]

for i in range(3):
    generate_concept(concept, mark_points=True, show_plots=True)
# Out:
# POINT (11.190079196003676 10.940610258213418) Obj c1: circle
# POINT (11.190079196003676 10.940610258213418)
# array('d', [11.190079196003676]) array('d', [10.940610258213418])
# POINT (15.87616285190028 13.062648140181455)
# array('d', [15.87616285190028]) array('d', [13.062648140181455])
# POINT (7.552605841972841 7.3031369041825815) Obj c2: circle
# POINT (7.552605841972841 7.3031369041825815)
# array('d', [7.552605841972841]) array('d', [7.3031369041825815])
# POINT (14.48599464125099 5.843521991226783)
# array('d', [14.48599464125099]) array('d', [5.843521991226783])
# POINT (15.166571857799331 7.67718706879192) Obj l3: line
# POINT (15.166571857799331 7.67718706879192)
# array('d', [15.166571857799331]) array('d', [7.67718706879192])
# POINT (14.629133111030784 7.123300007363186)
# array('d', [14.629133111030784]) array('d', [7.123300007363186])
# POINT (7.818362367258116 9.387788616359133) Obj c1: circle
# POINT (7.818362367258116 9.387788616359133)
# array('d', [7.818362367258116]) array('d', [9.387788616359133])
# POINT (14.07433847625354 3.605581079378835)
# array('d', [14.07433847625354]) array('d', [3.605581079378835])
# POINT (6.156413103985846 1.0326054512009897) Obj c2: circle
# POINT (6.156413103985846 1.0326054512009897)
# array('d', [6.156413103985846]) array('d', [1.0326054512009897])
# POINT (1.4189591370428438 13.768728189074896)
# array('d', [1.4189591370428438]) array('d', [13.768728189074896])
# POINT (-0.5368207979000275 7.72583935308686) Obj l3: line
# POINT (-0.5368207979000275 7.72583935308686)
# array('d', [-0.5368207979000275]) array('d', [7.72583935308686])
# POINT (16.304916138974765 10.045618476023192)
# array('d', [16.304916138974765]) array('d', [10.045618476023192])
# POINT (6.3920498833236525 9.314128450738844) Obj c1: circle
# POINT (6.3920498833236525 9.314128450738844)
# array('d', [6.3920498833236525]) array('d', [9.314128450738844])
# POINT (10.913100000650594 3.8001924897704757)
# array('d', [10.913100000650594]) array('d', [3.8001924897704757])
# POINT (10.353518251485722 3.3853720623304397) Obj c2: circle
# POINT (10.353518251485722 3.3853720623304397)
# array('d', [10.353518251485722]) array('d', [3.3853720623304397])
# POINT (0.8671021513988588 15.515070455420625)
# array('d', [0.8671021513988588]) array('d', [15.515070455420625])
# POINT (15.667096139857923 10.406340114543498) Obj c1: circle
# POINT (15.667096139857923 10.406340114543498)
# array('d', [15.667096139857923]) array('d', [10.406340114543498])
# POINT (2.5227469633226747 10.300234451525558)
# array('d', [2.5227469633226747]) array('d', [10.300234451525558])
# POINT (7.3281376163877 0.2452897539631191) Obj c2: circle
# POINT (7.3281376163877 0.2452897539631191)
# array('d', [7.3281376163877]) array('d', [0.24528975396311914])
# POINT (11.31134010278811 9.421516135051531)
# array('d', [11.31134010278811]) array('d', [9.421516135051531])
# POINT (28.811873569940463 10.406340114543498) Obj l3: line
# POINT (28.811873569940463 10.406340114543498)
# array('d', [28.811873569940463]) array('d', [10.406340114543498])
# POINT (2.594676232552196 9.05683674772806)
# array('d', [2.594676232552196]) array('d', [9.05683674772806])
# POINT (3.9352584754943187 10.682324078673014) Obj c1: circle
# POINT (3.9352584754943187 10.682324078673014)
# array('d', [3.9352584754943187]) array('d', [10.682324078673014])
# POINT (5.714885781435314 4.455224700121553)
# array('d', [5.714885781435314]) array('d', [4.455224700121553])
# POINT (7.5333570951537805 16.06725920749411) Obj c2: circle
# POINT (7.5333570951537805 16.06725920749411)
# array('d', [7.5333570951537805]) array('d', [16.06725920749411])
# POINT (11.004144036176122 2.2235498978034993)
# array('d', [11.004144036176122]) array('d', [2.2235498978034993])
# POINT (0.3969684351432114 13.137404124020625) Obj c1: circle
# POINT (0.3969684351432114 13.137404124020625)
# array('d', [0.39696843514321145]) array('d', [13.137404124020625])
# POINT (12.01958097614706 13.524799050509044)
# array('d', [12.01958097614706]) array('d', [13.524799050509044])
# POINT (11.525291624552548 16.51314405763863) Obj c2: circle
# POINT (11.525291624552548 16.51314405763863)
# array('d', [11.525291624552548]) array('d', [16.51314405763863])
# POINT (0.9885420133360654 2.889396326749967)
# array('d', [0.9885420133360654]) array('d', [2.889396326749967])
# POINT (10.066184187027805 6.676640713178548) Obj l3: line
# POINT (10.066184187027805 6.676640713178548)
# array('d', [10.066184187027805]) array('d', [6.676640713178548])
# POINT (-4.012073943477986 23.896005786759535)
# array('d', [-4.012073943477986]) array('d', [23.896005786759535])
