# %%
import sys
sys.path.append("..")
from geoclidean_env_euclid import *
import numpy as np
import os
import shutil

# %%
concept = [
    'l1 = line(p1(), p2())',
    'c1* = circle(p1(), p2())',
    'c2* = circle(p2(), p1())',
    'l2 = line(p1(), p3(c1, c2))',
    'l3 = line(p2(), p3()))'
]


for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)
# Out:
# p1 p2
# POINT (10.539273712470212 2.8977405403995515) POINT (3.506366518519819 1.7623914189013288)
# p1 p2
# POINT (10.539273712470212 2.8977405403995515) POINT (3.506366518519819 1.7623914189013288)
# p2 p1
# POINT (3.506366518519819 1.7623914189013288) POINT (10.539273712470212 2.8977405403995515)
# p1 p3
# POINT (10.539273712470212 2.8977405403995515) POINT (6.0340191226437705 8.415120966280908)
# p2 p3
# POINT (3.506366518519819 1.7623914189013288) POINT (6.0340191226437705 8.415120966280908)
# p1 p2
# POINT (11.40266370532953 12.528800965739109) POINT (3.5202910311610687 3.4057654830674835)
# p1 p2
# POINT (11.40266370532953 12.528800965739109) POINT (3.5202910311610687 3.4057654830674835)
# p2 p1
# POINT (3.5202910311610687 3.4057654830674835) POINT (11.40266370532953 12.528800965739109)
# p1 p3
# POINT (11.40266370532953 12.528800965739109) POINT (15.36028321091025 1.1551492466792113)
# p2 p3
# POINT (3.5202910311610687 3.4057654830674835) POINT (15.36028321091025 1.1551492466792113)
# p1 p2
# POINT (0.9640337846159035 5.9859641633117615) POINT (8.517424071409685 15.36771473247571)
# p1 p2
# POINT (0.9640337846159035 5.9859641633117615) POINT (8.517424071409685 15.36771473247571)
# p2 p1
# POINT (8.517424071409685 15.36771473247571) POINT (0.9640337846159035 5.9859641633117615)
# p1 p3
# POINT (0.9640337846159035 5.9859641633117615) POINT (12.852138827674743 4.141781721631632)
# p2 p3
# POINT (8.517424071409685 15.36771473247571) POINT (12.852138827674743 4.141781721631632)

# %%
concept = [
    'c1 = circle(p1(), p2())',
    'c2 = circle(p3(c1), p4())',
    'l3 = line(p5(c1), p6(c1, c2))'
]

for i in range(3):
    generate_concept(concept, mark_points=True, show_plots=True)
# Out:
# p1 p2
# POINT (9.472712140982418 1.4930768812483457) POINT (9.411542277458048 14.187251222422415)
# p3 p4
# POINT (-2.2553118761656012 6.350983488988442) POINT (9.969985201599036 9.559188321247568)
# p5 p6
# POINT (-3.221609580020468 1.4930768812483441) POINT (7.748004071799435 14.055004399824899)
# p1 p2
# POINT (9.571136774916136 11.271115943034209) POINT (6.0807489070995295 8.799462943808448)
# p3 p4
# POINT (13.76585761659043 12.105497796148438) POINT (15.432221263240127 10.244506008932255)
# p5 p6
# POINT (9.571136774916136 15.548016224357477) POINT (12.583781979418863 14.305836622742158)
# p1 p2
# POINT (5.256025620543534 6.242894745229181) POINT (6.16528684496496 13.980485970648552)
# p3 p4
# POINT (6.019660761240742 13.996212442693636) POINT (5.217305352771207 3.5067408444133807)
# p5 p6
# POINT (3.736109562999456 -1.398239275578388) POINT (13.04384428034977 6.181542826510965)
# p1 p2
# POINT (13.386508004984734 11.821405191241432) POINT (12.897577865205859 9.418724755341405)
# p3 p4
# POINT (15.54891095822676 12.977233650162175) POINT (13.827112548773869 4.351315992290797)
# p1 p2
# POINT (7.066255009076297 15.019020594311913) POINT (13.80708686379073 4.225878881787532)
# p3 p4
# POINT (13.064872895674558 26.241645312743426) POINT (10.096940512157857 4.499106693832557)
# p5 p6
# POINT (18.822807093207317 10.149297274319167) POINT (-5.649764445015146 14.832140626507282)
