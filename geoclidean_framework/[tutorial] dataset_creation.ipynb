# %%
import sys
sys.path.append("..")
from geoclidean_env_euclid import *
import numpy as np
import os
import shutil

# %%
concept = [
    'l1 = line(p1(), p2())',
    'c1* = circle(p1(), p2())',
    'c2* = circle(p2(), p1())',
    'l2 = line(p1(), p3(c1, c2))',
    'l3 = line(p2(), p3()))'
]


for i in range(3):
    generate_concept(concept, mark_points=False, show_plots=True)

# %%
concept = [
    'c1 = circle(p1(), p2())',
    'c2 = circle(p3(c1), p4())',
    'l3 = line(p5(c1), p6(c1, c2))'
]

for i in range(3):
    generate_concept(concept, mark_points=True, show_plots=True)
# Out:
# POINT (12.295869367558504 10.565837495416416) Obj c1: circle
# POINT (13.411515446776006 7.872429600161153) Obj c2: circle
# POINT (6.586248333709248 6.375257268698629) Obj c1: circle
# POINT (-2.9080484047444077 9.25532069749255) Obj c2: circle
# POINT (15.752531857053848 10.172056220625008) Obj l3: line
# POINT (9.923900141435043 9.244465848137503) Obj c1: circle
# POINT (14.49159588764233 9.244465848137503) Obj c2: circle
# POINT (5.895552133781311 7.091268978561398) Obj l3: line
# POINT (11.518624160116858 2.4810129023224405) Obj c1: circle
# POINT (6.181027752440813 4.691917724855769) Obj c2: circle
# POINT (7.8534977064530365 -1.9849566031926846) Obj l3: line
